# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.6 MB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 23.6 MB/s eta 0:00:00
# ...

# %%
import nltk
import string
import random

nltk.download('words')
from nltk.corpus import words

# Get a list of valid English words
english_words = words.words()

# Filter words to start with each letter of the alphabet
words_by_starting_letter = {}
for letter in string.ascii_lowercase:
    words_by_starting_letter[letter] = [word.lower() for word in english_words if word.lower().startswith(letter)]

# Generate a list of 10,000 words with unique starting letters
selected_words = []
for letter in string.ascii_lowercase:
    if words_by_starting_letter[letter]:
        selected_words.append(random.choice(words_by_starting_letter[letter]))
    else:
        # If there are no words starting with a particular letter,
        # add a placeholder word to maintain the count
        selected_words.append(f"No word available for letter '{letter}'")

# Ensure there are exactly 10,000 words in the list
while len(selected_words) < 10000:
    remaining = 10000 - len(selected_words)
    random_word = random.choice(english_words)
    selected_words.append(random_word.lower())

# Print the first few words to display the array
print(selected_words)  # Displaying the first 10 words for example
# Out:
# [nltk_data] Downloading package words to /home/sudhar/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ...

# %%
# !python -m pip install --upgrade --user urllib3
# Out:
# ...
#   Obtaining dependency information for urllib3 from https://files.pythonhosted.org/packages/96/94/c31f58c7a7f470d5665935262ebd7455c7e4c7782eb525658d3dbf4b9403/urllib3-2.1.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 1.9 MB/s eta 0:00:00 0:00:01
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.21.0 requires urllib3<1.25,>=1.21.1, but you have urllib3 2.1.0 which is incompatible.
# opencanary 0.9.2 requires Twisted==22.8.0, but you have twisted 23.10.0 which is incompatible.
# opencanary 0.9.2 requires zope.interface==5.0.0, but you have zope-interface 6.1 which is incompatible.
# ...

# %%
from bs4 import BeautifulSoup
import requests

req = requests.get("https://www.behance.net/")
req
# Out:
# <Response [200]>

# %%
images = [
  {
    "name": "monkey1",
    "url": "https://cdn.pixabay.com/photo/2015/05/27/15/49/monkey-786858_1280.png",
  },
  {
    "name": "turtle1",
    "url": "https://cdn.pixabay.com/photo/2017/11/15/20/32/sea-turtle-2952470_1280.png",
  },
  {
    "name": "art1",
    "url": "https://cdn.pixabay.com/photo/2017/07/26/06/34/art-2540641_1280.png",
  },
  {
    "name": "monkey2",
    "url": "https://cdn.pixabay.com/photo/2015/05/27/15/49/monkey-786858_640.png",
  },
  {
    "name": "leaves1",
    "url": "https://cdn.pixabay.com/photo/2019/08/09/19/22/leaves-4395694_1280.png",
  },
  {
    "name": "turtle2",
    "url": "https://cdn.pixabay.com/photo/2017/11/15/20/32/sea-turtle-2952470_640.png",
  },
  {
    "name": "digitalArt1",
    "url": "https://cdn.pixabay.com/photo/2014/07/21/03/53/digital-art-398342_1280.png",
  },
  {
    "name": "tree1",
    "url": "https://cdn.pixabay.com/photo/2014/12/22/00/07/tree-576847_1280.png",
  },
  {
    "name": "doodle1",
    "url": "https://cdn.pixabay.com/photo/2018/06/29/08/15/doodle-3505459_1280.png",
  },
  {
    "name": "parrot1",
    "url": "https://cdn.pixabay.com/photo/2016/05/26/14/39/parrot-1417286_1280.png",
  },
  {
    "name": "elephant1",
    "url": "https://cdn.pixabay.com/photo/2018/07/09/17/44/baby-elephant-3526681_1280.png",
  },
  {
    "name": "trees1",
    "url": "https://cdn.pixabay.com/photo/2020/01/04/18/40/trees-4741364_1280.png",
#  {'name': 'monkey2',
#   'url': 'https://cdn.pixabay.com/photo/2015/05/27/15/49/monkey-786858_640.png'},
#  {'name': 'leaves1',
#   'url': 'https://cdn.pixabay.com/photo/2019/08/09/19/22/leaves-4395694_1280.png'},
#  {'name': 'turtle2',
#   'url': 'https://cdn.pixabay.com/photo/2017/11/15/20/32/sea-turtle-2952470_640.png'},
#  {'name': 'digitalArt1',
#   'url': 'https://cdn.pixabay.com/photo/2014/07/21/03/53/digital-art-398342_1280.png'},
#  {'name': 'tree1',
#   'url': 'https://cdn.pixabay.com/photo/2014/12/22/00/07/tree-576847_1280.png'},
#  {'name': 'doodle1',
#   'url': 'https://cdn.pixabay.com/photo/2018/06/29/08/15/doodle-3505459_1280.png'},
# ...

# %%
authors = [
    "John Doe",
    "Jane Smith",
    "Alex Johnson",
    "Emily Brown",
    "Michael Wilson",
  ]

import random

for i in range(len(images)):
    images[i]["author"] = random.choice(authors)

images
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mnt/New Volume/Project/behance-clone/Untitled-1.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/mnt/New%20Volume/Project/behance-clone/Untitled-1.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> authors = [
#       <a href='vscode-notebook-cell:/mnt/New%20Volume/Project/behance-clone/Untitled-1.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     "John Doe",
#       <a href='vscode-notebook-cell:/mnt/New%20Volume/Project/behance-clone/Untitled-1.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     "Jane Smith",
#    (...)
#       <a href='vscode-notebook-cell:/mnt/New%20Volume/Project/behance-clone/Untitled-1.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     "Michael Wilson",
#       <a href='vscode-notebook-cell:/mnt/New%20Volume/Project/behance-clone/Untitled-1.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>   ]
# ...

# %%
import json

with open("images.json", "w") as f:
    json.dump(images, f)

# %%
urls = [
  "https://media.istockphoto.com/id/1483773680/photo/ai-robot-painting-in-the-art-studio.webp?b=1&s=170667a&w=0&k=20&c=x4EkCzteqnADl545EJ-KsLYAmPU3OZ_z7Pzppnf5jTU=",
  "https://media.istockphoto.com/id/1408412202/photo/artists-hand-in-blue-gloves-with-paintbrush-painting-colorful-picture-at-outdoor-art-festival.webp?b=1&s=170667a&w=0&k=20&c=VU3QL9ANsEGMem-OqLoWYHawTRlO_KWnqrLEdPAd70E=",
  "https://media.istockphoto.com/id/1441581807/photo/white-wheat-paste-poster-style-texture-background.webp?b=1&s=170667a&w=0&k=20&c=mDDi5s13vaLowfNZU3Bb7gkXO2S1XCCQ_C0PXy8U36k=",
  "https://media.istockphoto.com/id/1550670587/photo/a-generative-artificial-intelligence-cpu-that-emits-colorful-light-3d-rendering.webp?b=1&s=170667a&w=0&k=20&c=S5rG55yB8wBjHH8BSIoXshEHFETXLHYffbTUBFFyiqI=",
  "https://media.istockphoto.com/id/1462545505/photo/girl-artist-hand-holds-paint-brush-and-draws-surreal-fairy-tale-portrait-on-white-canvas.webp?b=1&s=170667a&w=0&k=20&c=FOmeChoi0n9BKRPquoB2c0NGjtpShAd6UoaxQFl2z4c=",
  "https://media.istockphoto.com/id/1443440198/photo/a-girl-concentrates-on-acrylic-color-painting-on-canvas-in-an-art-classroom.webp?b=1&s=170667a&w=0&k=20&c=0Zu1G1rXsCRmF-4TSICC9J_NWvEb5kFy8k20nmhnpiQ=",
    path = parsed_url.path
    segments = path.split('/')
    filename = segments[-1]  # Get the last segment which represents the filename
    if '?' in filename:
        filename = filename.split('?')[0]  # Remove query parameters if present
    name:str = filename.split('/')[-1]  # Extract the name between the last /
    name = name.removesuffix(".webp").replace("-", " ")
    if len(s:=name.split())>3:
        name=" ".join(s[:3])
    return name

# Extract names from URLs
res = []
for i in urls:
    res.append({
        "name":extract_name_from_url(i),
        "url":i,
        "authors":random.choice(authors)
    })
res
# Out:
# [{'name': 'ai robot painting',
#   'url': 'https://media.istockphoto.com/id/1483773680/photo/ai-robot-painting-in-the-art-studio.webp?b=1&s=170667a&w=0&k=20&c=x4EkCzteqnADl545EJ-KsLYAmPU3OZ_z7Pzppnf5jTU=',
#   'authors': 'John Doe'},
#  {'name': 'artists hand in',
#   'url': 'https://media.istockphoto.com/id/1408412202/photo/artists-hand-in-blue-gloves-with-paintbrush-painting-colorful-picture-at-outdoor-art-festival.webp?b=1&s=170667a&w=0&k=20&c=VU3QL9ANsEGMem-OqLoWYHawTRlO_KWnqrLEdPAd70E=',
#   'authors': 'Jane Smith'},
#  {'name': 'white wheat paste',
#   'url': 'https://media.istockphoto.com/id/1441581807/photo/white-wheat-paste-poster-style-texture-background.webp?b=1&s=170667a&w=0&k=20&c=mDDi5s13vaLowfNZU3Bb7gkXO2S1XCCQ_C0PXy8U36k=',
#   'authors': 'Emily Brown'},
#  {'name': 'a generative artificial',
# ...

# %%
import json

with open("images.json", "w") as f:
    json.dump(res, f)

# %%
t = """https://mir-s3-cdn-cf.behance.net/projects/max_808/6100fa184434287.Y3JvcCwxNDcyLDExNTIsMjg4LDA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/6d3c5b184102733.Y3JvcCwxMzIwLDEwMzMsODEsNTAz.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/ae79b2175669275.Y3JvcCw0NTk3LDM1OTUsMCwxMQ.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/b5100d184596691.Y3JvcCwxMzU5LDEwNjMsMTIxLDA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/357d1f181509827.Y3JvcCwxODQxLDE0NDAsMzgyLDA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/d4dbcf159650005.Y3JvcCw4MDgsNjMyLDAsMA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/a9181f149513449.Y3JvcCw4NTMsNjY3LDIxOSw1NTM.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/d068ea172580173.Y3JvcCwxODUwLDE0NDcsMzIsMjMz.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/0b8303149277075.Y3JvcCwxNjYxLDEyOTksMCwxMDI.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/de7d59183199597.Y3JvcCwyODAwLDIxOTAsMCwzNTM.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/f53afe170787317.Y3JvcCwyNjMxLDIwNTgsMjAxLDA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/f083c1184609651.Y3JvcCwxMzYyLDEwNjYsMjAsMA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/5f730e153109427.Y3JvcCw5MjAsNzIwLDIzOSww.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/c3442b157682849.Y3JvcCwxMzEzLDEwMjcsNDIsMA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/ab54e3181849621.Y3JvcCwzNTA5LDI3NDQsMCw0NTE.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/70911a170181669.Y3JvcCwxMjY0LDk4OCw3MSww.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/7282e3157230631.Y3JvcCw0NTAwLDM1MTksMCw0OTA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/f46a28179113527.Y3JvcCw4MDgsNjMyLDAsMA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/55efd5153217463.Y3JvcCwxMTM0LDg4Niw0MDQsMTA2.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/20a378111288083.Y3JvcCwxMDEzLDc5Myw1OTIsMA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/d17523167859847.Y3JvcCwxNjUwLDEyOTEsMTE4LDA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/e986bc149315971.Y3JvcCwxMDM5LDgxMiwwLDc.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/43dd67184533691.Y3JvcCw5MzcsNzMzLDksMA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/fc3b40175169965.Y3JvcCwxMzgwLDEwODAsMjcwLDA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/837cac133749373.Y3JvcCwyMjYyLDE3NzAsMCww.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/e21550136313627.Y3JvcCw4MDgsNjMyLDAsMA.png
https://mir-s3-cdn-cf.behance.net/projects/max_808/60ec9d161216893.Y3JvcCwyMTU5LDE2ODgsMCw2OQ.png
https://mir-s3-cdn-cf.behance.net/projects/404/6100fa184434287.Y3JvcCwxNDcyLDExNTIsMjg4LDA.
sMA.png
https://mir-s3-cdn-cf.behance.net/projects/115/70911a170181669.Y3JvcCwxMjY0LDk4OCw3MSww.png
https://mir-s3-cdn-cf.behance.net/projects/115/ab54e3181849621.Y3JvcCwzNTA5LDI3NDQsMCw0NTE.png
https://mir-s3-cdn-cf.behance.net/projects/115/7282e3157230631.Y3JvcCw0NTAwLDM1MTksMCw0OTA.png
https://mir-s3-cdn-cf.behance.net/projects/115/f46a28179113527.Y3JvcCw4MDgsNjMyLDAsMA.png
https://mir-s3-cdn-cf.behance.net/projects/115/55efd5153217463.Y3JvcCwxMTM0LDg4Niw0MDQsMTA2.png
https://mir-s3-cdn-cf.behance.net/projects/115/20a378111288083.Y3JvcCwxMDEzLDc5Myw1OTIsMA.png
https://mir-s3-cdn-cf.behance.net/projects/115/d17523167859847.Y3JvcCwxNjUwLDEyOTEsMTE4LDA.png
https://mir-s3-cdn-cf.behance.net/projects/115/e986bc149315971.Y3JvcCwxMDM5LDgxMiwwLDc.png
https://mir-s3-cdn-cf.behance.net/projects/115/fc3b40175169965.Y3JvcCwxMzgwLDEwODAsMjcwLDA.png
https://mir-s3-cdn-cf.behance.net/projects/115/837cac133749373.Y3JvcCwyMjYyLDE3NzAsMCww.png
https://mir-s3-cdn-cf.behance.net/projects/115/43dd67184533691.Y3JvcCw5MzcsNzMzLDksMA.png
https://mir-s3-cdn-cf.behance.net/projects/115/e21550136313627.Y3JvcCw4MDgsNjMyLDAsMA.png
https://mir-s3-cdn-cf.behance.net/projects/115/6180c2100945189.Y3JvcCwxNTM0LDEyMDAsMzQsMA.png
https://mir-s3-cdn-cf.behance.net/projects/115/3a4e9c163598625.Y3JvcCw1ODUsNDU3LDQ2OSwxNzk.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/photography.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/graphic-design.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/indesign.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/network.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/illustration.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/photoshop.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/ui-ux.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/fashion.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/3d-art.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/after-effects.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/illustrator.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/motion.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/stock.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/product-design.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/adve.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/xd.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/fine-arts.png?cb=264615658
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/network.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/graphic-design.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/indesign.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/ui-ux.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/photoshop.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/illustration.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/photography.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/fashion.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/3d-art.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/after-effects.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/illustrator.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/motion.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/stock.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/product-design.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/architecture.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/galleries/icons/ribbons/1x/adve.png
https://a5.behance.net/8877ccab6fe58b7fd0df40cb3f0d7b68f29e6263/img/search/colorWheel.png"""
t = t.split("\n")

# %%
cat = [
"Projects",
"Assets",
"Images",
"Prototype",
"Streams",
"People",
"Moodbord",
]
res = []
for i in t:
    res.append({
        "name":random.choice(selected_words),
        "url":i,
        "authors":random.choice(authors),
        "likes":random.randint(0,1000000),
        "views":random.randint(0,1000000),
        "catogary":random.choice(cat)
    })
res
# Out:
# [{'name': 'antheriferous',
#   'url': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/6100fa184434287.Y3JvcCwxNDcyLDExNTIsMjg4LDA.png',
#   'authors': 'Michael Wilson',
#   'likes': 827982,
#   'views': 879459,
#   'catogary': 'Moodbord'},
#  {'name': 'thymectomy',
#   'url': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/6d3c5b184102733.Y3JvcCwxMzIwLDEwMzMsODEsNTAz.png',
#   'authors': 'Michael Wilson',
#   'likes': 551142,
#   'views': 386564,
#   'catogary': 'Images'},
#  {'name': 'unbleeding',
#   'url': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/ae79b2175669275.Y3JvcCw0NTk3LDM1OTUsMCwxMQ.png',
#   'authors': 'John Doe',
#   'likes': 963877,
#   'views': 757758,
#   'catogary': 'Projects'},
#  {'name': 'drightin',
#   'url': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/b5100d184596691.Y3JvcCwxMzU5LDEwNjMsMTIxLDA.png',
#   'authors': 'Jane Smith',
#   'likes': 474667,
#   'views': 342241,
#   'catogary': 'Moodbord'},
#  {'name': 'photospectroscopy',
# ...
